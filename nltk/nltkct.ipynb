# %%
import nltk
import html5lib
import spicy
import spacy

# %% [markdown]
# # Tokenizar Texto

# %%
# LEER TEXTO DESDE URL
print("Equipo Pedro Figueroa, Cesar Salim, Paul Razon")
from bs4 import BeautifulSoup
 
import urllib.request
  
response = urllib.request.urlopen('https://es.wikipedia.org/wiki/Wikipedia:Portada') #Obtiene el contenido HTML de la página web http://librefinanciero.com/
 
html = response.read()
 
soup = BeautifulSoup(html,"html5lib") # Limpia el texto HTML capturado
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# Cisco Networking Academy Builds IT Skills & Education For Future Careers//GTM Loader Configuration
#   window["dataLayer"] = window["dataLayer"] || [];
#   window["dataLayer"].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
#   //End of GTM Configuration
#
#   window['adrum-start-time'] = new Date().getTime();
#   (function(config){
#     config.appKey = 'AD-AAB-ABN-FEG';
#     config.adrumExtUrlHttp = 'http://cdn.appdynamics.com';
#     config.adrumExtUrlHttps = 'https://cdn.appdynamics.com';
#     config.beaconUrlHttp = 'http://col.eum-appdynamics.com';
#     config.beaconUrlHttps = 'https://col.eum-appdynamics.com';
#     config.xd = {enable : true};
#   })(window['adrum-config'] || (window['adrum-config'] = {}));
#
#     var sc = document.createElement("script");
#     sc.setAttribute("type", "text/javascript");
#     sc.setAttribute("charset", "UTF-8");
#     var url="cdn.appdynamics.com/adrum/adrum-latest.js";
#
#     url = document.location.protocol === 'https:' ? "https://"+url : "http://"+url;
#     sc.setAttribute("src", url);
#     document.head.appendChild(sc);jQuery.migrateMute=true;jQuery.migrateTrace=false;jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"es\/","setHasJsCookie":0,"ajaxPageState":{"theme":"prelogin","theme_token":"ovRrrUptlJSNNrCVoGMjFSnaKxt0WphTNS1qsygw3jM","js":{"0":1,"sites\/all\/themes\/contrib\/bootstrap\/js\/bootstrap.js":1,"sites\/all\/themes\/custom\/prelogin\/script.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/3.5\/jquery.min.js":1,"1":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery-migrate\/3\/jquery-migrate.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery.form\/4\/jquery.form.min.js":1,"sites\/all\/modules\/custom\/netacad_virtual_bot\/js\/netacad_virtual_bot.js":1,"sites\/all\/modules\/contrib\/lazyloader\/jquery.lazyloader.js":1,"public:\/\/languages\/es_Shkep0V70t-Dz5z4o-4_Bs87oKK8q5QINEGCfEYnUb4.js":1,"sites\/all\/modules\/contrib\/behavior_weights\/behavior_weights.js":1,"sites\/all\/libraries\/ddslick\/jquery.ddslick.min.js":1,"sites\/all\/modules\/contrib\/ctools\/js\/auto-submit.js":1,"sites\/all\/modules\/contrib\/lang_dropdown\/lang_dropdown.js":1,"sites\/all\/modules\/contrib\/extlink\/js\/extlink.js":1,"sites\/all\/themes\/custom\/prelogin\/netacadcolorbox\/colorbox_netacadcolorbox.js":1,"sites\/all\/themes\/custom\/prelogin\/bootstrap.min.js":1,"sites\/all\/themes\/custom\/prelogin\/slide-menu.js":1},"css":{"modules\/system\/system.base.css":1,"sites\/all\/modules\/contrib\/deploy\/css\/deploy.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/contrib\/extlink\/css\/extlink.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/lazyloader\/lazyloader.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/modules\/contrib\/lang_dropdown\/ddslick\/ddsDefault.css":1,"modules\/locale\/locale.css":1,"sites\/all\/modules\/contrib\/addtoany\/addtoany.css":1,"sites\/all\/themes\/custom\/prelogin\/assets\/css\/bootstrap.css":1,"sites\/all\/themes\/custom\/prelogin\/assets\/css\/cui-standard.min.css":1,"sites\/all\/themes\/custom\/prelogin\/assets\/css\/styles.css":1,"sites\/all\/themes\/custom\/prelogin\/assets\/css\/custom.css":1,"sites\/all\/themes\/custom\/prelogin\/css\/style.css":1,"sites\/all\/themes\/custom\/prelogin\/netacadcolorbox\/colorbox_netacadcolorbox.css":1}},"urlIsAjaxTrusted":{"\/es":true},"lang_dropdown":{"language":{"jsWidget":{"widget":"ddslick","width":"120","height":"0","showSelectedHTML":1,"imagePosition":"left"},"selectedOption":"es","globallang":{"language":"es","name":"Spanish","native":"Espa\u00f1ol","direction":"0","enabled":"1","plurals":"2","formula":"($n!=1)","domain":"","prefix":"es","weight":"-2","javascript":"Shkep0V70t-Dz5z4o-4_Bs87oKK8q5QINEGCfEYnUb4","provider":"locale-url","dir":"ltr"},"sessionlang":"","setLang":true,"langOption":{"href":"\u003Cfront\u003E","title":"Espa\u00f1ol","language":{"language":"es","name":"Spanish","native":"Espa\u00f1ol","direction":"0","enabled":"1","plurals":"2","formula":"($n!=1)","domain":"","prefix":"es","weight":"-2","javascript":"Shkep0V70t-Dz5z4o-4_Bs87oKK8q5QINEGCfEYnUb4"},"attributes":{"class":["language-link"],"xml:lang":"es","hreflang":"es"}}}},"user_js_uid":0,"postlogin_url":"https:\/\/www.netacad.com\/portal","extlink":{"extTarget":"_blank","extClass":0,"extLabel":"(link is external)","extImgClass":0,"extIconPlacement":0,"extSubdomains":1,"extExclude":"","extInclude":"","extCssExclude":"","extCssExplicit":"","extAlert":0,"extAlertText":"This link will take you to an external web site ...
#
#
# .csr-text, .follow-title {color:#FFFFFF;}
#
# .container a:link {
# 	color: #0070D2;
# 	text-decoration: underline;
# }
# .container a:visited {
# 	color: #0070D2;
# 	text-decoration: underline;
# }
# .container a:hover {
# 	color: #0060AD;
# /* 	color: #0070D2; */
# 	text-decoration: underline;
# }
# .container a:active {
# 	color: #0070D2;
# 	text-decoration: underline;
# }
#
# .container h1,.container h2,.col-md-5 h2,.panel-pane h2,.container h3 {
# 	color: #1b1c1d;
# 	font-size: 40px;
# 	margin-bottom: 0px;
# 	font-weight: 100;
# }
#
# .container h1 {
# 	font-size: 64px;
# 	line-height: 77px;
# }
# .container. h2,.col-md-5 h2,.panel-pane h2 {
# 	font-size: 40px !important;
# 	line-height: 48px;
# }
# .container h3,.panel-pane .pane-content h3 {
# 	font-size: 32px !important;
# 	line-height: 40px;
# }
#
#
# @media only screen and (min-width: 1439px) {
# .container h1 {
# 	font-size: 64px;
# 	line-height: 77px
#     }
# }
# @media only screen and (min-width: 600px)and (max-width: 1439px) {
# .container h1 {
# 	font-size: 52px;
# 	line-height: 62px
#     }
# }
# @media only screen and (max-width: 599px) {
# .container h1 {
# 	font-size: 32px;
# 	line-height: 40px;
# 	font-weight: 300
#     }
# }
#
# .hero-bg-img {background-image: url(/sites/default/files/home-hero-25th-800.png);}
# .hero-text {font-size:1.3em;}
#
# p, .container .row .col-md-4 .panel p {
# 	color: #1b1c1d;
# 	font-size: 16px;
# 	line-height: 24px;
# }
#
# .cta-blue,.container .field .field-items .field-item .cta-blue,.container .row .col-md .cta-blue,.row .col-md-12 .cta-blue,.row .col-md-5 .cta-blue {
# 	font-size: 16px;
# 	line-height: 24px;
# 	font-weight: 500;
# 	color: #fff;
# 	background-color: #0070D2;
# 	z-index: 1;
# 	text-align: center;
# 	text-decoration: none;
# }
# .cta-blue:hover,.cta-blue:visited,.cta-blue:focus{
#     color:#fff !important;
#     text-decoration:none !important
# }
# .cta-blue:hover {
#     background-color: #0060AD !important;
# }
#
# .cta-blue-hero,.container .field .field-items .field-item .cta-blue-hero,.container .row .col-md .cta-blue-hero,.row .col-md-12 .cta-blue-hero,.row .col-md-5 .cta-blue-hero {
# 	border-radius: 10px;
# 	padding: 10px 16px;
# 	margin-right: 8px;
# 	margin-bottom: 8px;
# 	}
# .cta-blue-hero-sm,.container .field .field-items .field-item .cta-blue-hero-sm,.container .row .col-md .cta-blue-hero-sm,.row .col-md-12 .cta-blue-hero-sm,.row .col-md-5 .cta-blue-hero-sm {
# 	font-size: 14px;
# 	border-radius: 10px;
# 	padding: 6px 12px;
# 	margin-right: 8px;
# 	margin-bottom: 8px;
# 	}
# .cta-blue-hero-sm-last,.container .field .field-items .field-item .cta-blue-hero-sm-last,.container .row .col-md .cta-blue-hero-sm-last,.row .col-md-12 .cta-blue-hero-sm-last,.row .col-md-5 .cta-blue-hero-sm-last {
# 	font-size: 14px;
# 	border-radius: 10px;
# 	padding: 6px 12px;
# 	margin-right: 0px;
# 	margin-bottom: 8px;
# 	}
# .cta-blue-lg,.container .field .field-items .field-item .cta-blue-lg,.container .row .col-md .cta-blue-lg,.row .col-md-12 .cta-blue-lg,.row .col-md-5 .cta-blue-lg {
# 	border-radius: 48px;
# 	padding: 16px 32px;
# 	}
#
# .cta-blue-md,.container .field .field-items .field-item .cta-blue-md,.container .row .col-md .cta-blue-md,.row .col-md-12 .cta-blue-md,.row .col-md-5 .cta-blue-md {
# 	border-radius: 48px;
# 	padding: 12px 32px;
# 	margin-right: 8px;
# 	}
#
# .cta-blue-sm,.container .field .field-items .field-item .cta-blue-sm,.container .row .col-md .cta-blue-sm,.row .col-md-12 .cta-blue-sm,.row .col-md-5 .cta-blue-sm {
# 	border-radius: 48px;
# 	padding: 8px 32px;
# 	}
#
# .cta-blue-xsm,.container .field .field-items .field-item .cta-blue-xsm,.container .row .col-md .cta-blue-xsm,.row .col-md-12 .cta-blue-xsm,.row .col-md-5 .cta-blue-xsm {
#
# 	border-radius: 8px;
# 	padding: 6px 16px;
# 	margin-left: 0px !important;
# }
#
# .card {
# 	padding:27px !important;
# 	border: none !important;
# 	}
#
# .card {
# 	border-image-width: 0px;
# 	}
#
# .card-title {
# 	margin-bottom:12px;
#     font-weight:300 !important;
#     font-size:20px;
#     line-height:28px;
#     color: #1B1C1D;
# 	}
# .card-description {
# 	color: #606162;
#     margin-bottom:24px;
# 	font-weight:300 !important;
#     font-size:16px;
#     line-height:24px;
#     color: #606162;
# 	}
# .card-cta {
#     font-size:16px;
# 	font-weight:600 !important;
# 	margin-bottom: 15px !important;
# 	}
#
#
# .back-blue {background-color: #f2fbfd;}
# .back-gray {background-color: #f2f2f2;}
#
# .stat {
# 	color: #0070D2;
# 	font-size: 26px;
# 	line-height: 40px;
# 	margin-bottom: 0px;
# 	font-weight: 100;
# }
#
# .icons {height: 120px;}
#
# .form-button {margin-top: -5px; margin-left: 0px;}
#
# /*
# #footer-links-2 a:link {
# 	color: #1b1c1d;
# }
# #footer-links-2 a:visited {
# 	color: #1b1c1d;
# }
# #footer-links-2 a:hover {
# 	color: #1b1c1d;
# }
# #footer-links-2 a:active {
# 	color: #1b1c1d;
# }
#
# #footer-links-2a a:link {
# 	color: #1b1c1d;
# }
# #footer-links-2a a:visited {
# 	color: #1b1c1d;
# }
# #footer-links-2a a:hover {
# 	color: #1b1c1d;
# }
# #footer-links-2a a:active {
# 	color: #1b1c1d;
# }
# */
#
# .pad-top-1 {padding-top: 10px;}
# .pad-top-2 {padding-top: 20px;}
# .pad-top-3 {padding-top: 30px;}
# .pad-top-4 {padding-top: 40px;}
# .pad-top-5 {padding-top: 50px;}
# .pad-top-6 {padding-top: 60px;}
# .pad-top-7 {padding-top: 70px;}
# .pad-top-8 {padding-top: 80px;}
# .pad-top-9 {padding-top: 90px;}
#
#
# .pad-bottom-05 {padding-bottom: 5px;}
# .pad-bottom-1 {padding-bottom: 10px;}
# .pad-bottom-2 {padding-bottom: 20px;}
# .pad-bottom-3 {padding-bottom: 30px;}
# .pad-bottom-4 {padding-bottom: 40px;}
# .pad-bottom-5 {padding-bottom: 50px;}
# .pad-bottom-6 {padding-bottom: 60px;}
#
# .pad-0 {padding: 0px !important;}
# .pad-1 {padding: 10px;}
# .pad-2 {padding: 20px;}
#
# .margin-bottom-1 {margin-bottom: 10px;}
# .margin-bottom-2 {margin-bottom: 20px;}
# .margin-bottom-3 {margin-bottom: 10px;}
#
# .divider-vertical {border-left: 2px solid #DFDFDF; height: 115px; position: absolute; left: 50%; margin-left: -1px; top: 0;}
# .divider-horizontal {border-top: 2px solid #0070D2;}
#
# .img-responsive {width: 100%; height: auto;}
#
#
# /*--><!]]>*/Aprenda la tecnología, consiga el trabajo de sus sueños.¿Está listo para comenzar, cambiar o impulsar su carrera? Cisco Networking Academy ofrece cursos alineados con las certificaciones en temas tales comociberseguridad,redesyPython.EstudiantesEducadoresEmpleadoresPartnersEstudiantesEducadoresEmpleadoresPartners17,5 millonesde estudiantes desde nuestros inicios en 199729 300educadores en todo el mundo11 800Organizaciones que ofrecen nuestros cursos190países donde prestamos servicios a los estudiantes95 %Los estudiantes obtuvieron un trabajo o una nueva oportunidad educativa*Explore nuestros cursosDesarrollado por expertos en tecnología en función de la ciencia de aprendizajeRedesCybersecurityInternet de las cosasProgramaciónAutomatización de la infraestructuraCursos dePacket TracerDatos×Este curso se ofrece actualmente en nuestro sitio web Skills For All.Se lo redirigirá al sitio webHabilidades para todoscon Cisco. Una vez allí, haga clic en Comience para inscribirse en el curso.Si la ventana no se ha abierto, seleccione este enlace:Habilidades para todos<!--//--><![CDATA[// ><!--
#
#     const boxes = document.getElementsByClassName('dataLink');
#     var isLoggedIn = Drupal.settings.user_js_uid;
#     if(isLoggedIn !=0){
#     isLoggedIn = 1;
#     }
#     for (const box of boxes) {
#         box.addEventListener('click', function onClick() {
#     setTimeout(function(){
#                 window.open('https://skillsforall.com/course/introduction-data-science?utm_source=netacad.com&utm_medium=referral&utm_campaign=home-data&userLang=en-US&userlogin='+isLoggedIn, '_blank');
#             }, 5000);
#     })
#     }
#
#     document.getElementsByClassName('close')[0].addEventListener("click", function() {
#         top.location.href = top.location.href;
#     })
#
# //--><!]]>Comience a aprenderDesarrolle habilidades que harán que lo soliciten en todas partes.Clases en línea gratuitasAprenda a su propio ritmo con cursos personalizados de expertos del sector. Junte tarjetas de identificación y prepárese para certificaciones reconocidas por el sector.Vea todas las clasesAprendizaje en personaAprenda de los educadores expertos en una academia cercana.Encuentra una ubicación cerca de tiCiudad y estado, provincia o distrito, o código postalBuscar¿Se está preparando para una carrera profesional?Le cubrimos las espaldas.CertificacionesPrepárese para certificaciones, comoCCNAyPython Institute, para validar sus habilidades. Muchos cursos se alinean con las credenciales del sector.Más informaciónCoincidencia de trabajoCoincidencia de trabajoDescubra quién está contratando y obtenga acceso prioritario a oportunidades deAmazon, IBM, Verizony nuestros otros partners de empleo.RegistrarseEmpiece a enseñarEnseñe sus pasiones y sea parte de una comunidad de más de 29 000 educadores en todo el mundo.Currículo y recursos didácticos gratuitosEl equipo y el software que necesitaOportunidades de desarrollo profesionalAyude a los estudiantes a obtener empleos con nuestro motor de coincidencia de empleosMás información¿Desea contratar a los mejores talentos?Automatizamos la conexión entre los empleadores y los mejores talentos de los partners educativos de Cisco Networking Academysin costo.Explore Talent BridgeColaboremos para lograr un impacto socialSe unirá a lasNaciones Unidas, laCasa Blancay muchas de las organizacionessin fines de lucroque conoce y ama.Cómo nos asociamosInspíreseHistorias de éxito inspiradoras de estudiantes y educadores de todo el mundo.La TI prepara el camino para salir de la pobrezaUna joven sudafricana descubrió su pasión por la tecnología, que la ayudó a salir de la pobreza a ella y a su familia.Lea el artículo>Estudiante descubre oportunidadesUn programa de TI innovador y el currículo de CCNA despertaron el interés de un joven y lo pusieron en un camino de independencia y prosperidad.Lea el artículo>Mujeres que lideran con el ejemploUna universidad de Arabia Saudita adoptó el currículo de Cisco Networking Academy para expandir las opciones de empleo a las mujeres y ayudarlas a progresar en su desarrollo profesional.Lea el artículo>Vea todas las historias*En función de las respuestas a la encuesta de 2005 al año fiscal 2022 de estudiantes que tomaron cursos alineados con la certificación de Cisco.¿Necesita ayuda?Pregunte a nuestroasistente virtual.CursosQuiénes somosEncuentre una academiaApoyoEnseña con nosotrosContrate con nosotrosSea nuestro partnerSíganosCisco Networking Academy es un programa global de educación en ciberseguridad y TI que se asocia con instituciones de aprendizaje de todo el mundo para empoderar a todas las personas con oportunidades profesionales. Es el programa deresponsabilidad social corporativamás grande y de más larga duración de Cisco.Términos y condicionesDeclaración de privacidadPolítica sobre las cookiesProtección de DatosAccesibilidadMarcas comerciales<!--/*--><![CDATA[/* ><!--*/
# .csr-text{
#  font-size: 12px;
# }
#
# /*--><!]]>*/img[data-src] { display: none !important; }(function ($) {
#         Drupal.behaviors.lazyloader = {
#           attach: function (context, settings) {
#             $("img[data-src]").lazyloader({distance: 500, icon: "" });
#           }
#         };
#       }(jQuery));

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['cisco', 'networking', 'academy', 'builds', 'it', 'skills', 'education', 'for', 'future', 'loader', 'configuration', 'window', 'datalayer', 'window', 'datalayer', 'window', 'datalayer', 'new', 'date', 'event', 'of', 'gtm', 'configuration', 'window', 'new', 'date', 'function', 'config', 'enable', 'true', 'window', 'window', 'var', 'sc', 'script', 'type', 'charset', 'var', 'url', 'https', 'http', 'src', 'url', 'sc', 'basepath', 'pathprefix', 'sethasjscookie', 'ajaxpagestate', 'theme', 'prelogin', 'js', 'public', 'public', 'css', 'urlisajaxtrusted', 'true', 'language', 'jswidget', 'widget', 'ddslick', 'width', 'height', 'showselectedhtml', 'imageposition', 'left', 'selectedoption', 'es', 'globallang', 'language', 'es', 'name', 'spanish', 'native', 'direction', 'enabled', 'plurals', 'formula', 'n', 'domain', 'prefix', 'es', 'weight', 'javascript', 'provider', 'dir', 'ltr', 'sessionlang', 'setlang', 'true', 'langoption', 'href', 'title', 'language', 'language', 'es', 'name', 'spanish', 'native', 'direction', 'enabled', 'plurals', 'formula', 'n', 'domain', 'prefix', 'es', 'weight', 'javascript', 'attributes', 'class', 'xml', 'lang', 'es', 'hreflang', 'es', 'https', 'extlink', 'exttarget', 'extclass', 'extlabel', 'link', 'is', 'external', 'extimgclass', 'exticonplacement', 'extsubdomains', 'extexclude', 'extinclude', 'extcssexclude', 'extcssexplicit', 'extalert', 'extalerttext', 'this', 'link', 'will', 'take', 'you', 'to', 'an', 'external', 'web', 'site', 'mailtoclass', 'mailtolabel', 'link', 'sends', 'extusefontawesome', 'false', 'lazyloader', 'loadimagedelay', 'bootstrap', 'anchorsfix', 'anchorssmoothscrolling', 'formhaserror', 'popoverenabled', 'popoveroptions', 'animation', 'html', 'placement', 'right', 'selector', 'trigger', 'click', 'triggerautoclose', 'title', 'content', 'delay', 'container', 'body', 'tooltipenabled', 'tooltipoptions', 'animation', 'html', 'placement', 'auto', 'left', 'selector', 'trigger', 'hover', 'focus', 'delay', 'container', 'body', 'pasar', 'al', 'contenido', 'principalcursosredesso', 'y', 'tiprogramacióninternet', 'de', 'las', 'cosasautomatización', 'de', 'infraestructuraciberseguridadpacket', 'tracertodos', 'los', 'cursoscarreras', 'profesionalesoportunidades', 'de', 'empleowebinarsasesoramiento', 'profesionalrutasinsignias', 'y', 'certificacioneshistorias', 'de', 'éxitoapoyomásquiénes', 'somospodcastcsr', 'blogformulario', 'de', 'búsquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañoliriniciar', 'sesióniniciar', 'sesiónse', 'te', 'olvidó', 'tu', 'contraseñareenviar', 'correo', 'electrónico', 'de', 'activacióncanjear', 'token', 'de', 'plazaapoyoactualizaciones', 'de', 'inicio', 'de', 'sesión', 'de', 'netacadpara', 'iniciar', 'sesión', 'utilice', 'el', 'correo', 'electrónico', 'y', 'la', 'contraseña', 'para', 'iniciar', 'utilice', 'el', 'nombre', 'de', 'la', 'pantalla', 'ni', 'el', 'nombre', 'de', 'de', 'inicio', 'de', 'sesión', 'borre', 'el', 'historial', 'y', 'el', 'caché', 'del', 'navegador', 'y', 'aún', 'tiene', 'problemas', 'consulte', 'laspreguntas', 'frecuentespara', 'obtener', 'usted', 'es', 'un', 'usuario', 'de', 'idioma', 'árabe', 'haga', 'clic', 'aquípara', 'obtener', 'más', 'me', 'muestres', 'este', 'mensaje', 'otra', 'vezinicie', 'sesión', 'en', 'netacadenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañolhomecursosredesso', 'y', 'tiprogramacióninternet', 'de', 'las', 'cosasautomatización', 'de', 'infraestructuraciberseguridadpacket', 'tracertodos', 'los', 'cursoscarreras', 'profesionalesoportunidades', 'de', 'empleowebinarsasesoramiento', 'profesionalrutasinsignias', 'y', 'certificacioneshistorias', 'de', 'éxitoapoyomásquiénes', 'somospodcastcsr', 'bloghomeiniciar', 'sesióniniciar', 'sesiónse', 'te', 'olvidó', 'tu', 'contraseñareenviar', 'correo', 'electrónico', 'de', 'activacióncanjear', 'token', 'de', 'plazaapoyolog', 'out', 'cdata', 'color', 'ffffff', 'a', 'link', 'color', 'underline', 'a', 'visited', 'color', 'underline', 'a', 'hover', 'color', 'color', 'underline',  ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# cisco:5
# networking:5
# academy:4
# builds:1
# it:1
# skills:2
# education:1
# for:3
# future:1
# loader:1
# configuration:2
# window:6
# datalayer:3
# new:2
# date:2
# event:1
# of:2
# gtm:1
# function:6
# config:1
# enable:1
# true:3
# var:3
# sc:2
# script:1
# type:1
# charset:1
# url:3
# https:2
# http:1
# src:1
# basepath:1
# pathprefix:1
# sethasjscookie:1
# ajaxpagestate:1
# theme:1
# prelogin:1
# js:1
# public:2
# css:1
# urlisajaxtrusted:1
# language:4
# jswidget:1
# widget:1
# ddslick:1
# width:2
# height:4
# showselectedhtml:1
# imageposition:1
# left:3
# selectedoption:1
# es:10
# globallang:1
# name:2
# spanish:2
# nosotrossea:1
# partnersíganoscisco:1
# global:1
# educación:1
# ciberseguridad:1
# asocia:1
# instituciones:1
# aprendizaje:1
# mundo:1
# empoderar:1
# personas:1
# profesionales:1
# deresponsabilidad:1
# social:1
# corporativamás:1
# grande:1
# larga:1
# duración:1
# condicionesdeclaración:1
# privacidadpolítica:1
# sobre:1
# cookiesprotección:1
# datosaccesibilidadmarcas:1
# comerciales:1
# display:1
# attach:1
# context:1
# settings:1
# img:1
# distance:1
# icon:1
# jquery:1

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 2. Eliminar Palabras de Parada

# %%
from nltk.corpus import stopwords

clean_tokens = tokens[:]
 
for token in tokens:
 
    if token in stopwords.words('spanish'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['cisco', 'networking', 'academy', 'builds', 'it', 'skills', 'education', 'for', 'future', 'loader', 'configuration', 'window', 'datalayer', 'window', 'datalayer', 'window', 'datalayer', 'new', 'date', 'event', 'of', 'gtm', 'configuration', 'window', 'new', 'date', 'function', 'config', 'enable', 'true', 'window', 'window', 'var', 'sc', 'script', 'type', 'charset', 'var', 'url', 'https', 'http', 'src', 'url', 'sc', 'basepath', 'pathprefix', 'sethasjscookie', 'ajaxpagestate', 'theme', 'prelogin', 'js', 'public', 'public', 'css', 'urlisajaxtrusted', 'true', 'language', 'jswidget', 'widget', 'ddslick', 'width', 'height', 'showselectedhtml', 'imageposition', 'left', 'selectedoption', 'globallang', 'language', 'name', 'spanish', 'native', 'direction', 'enabled', 'plurals', 'formula', 'n', 'domain', 'prefix', 'weight', 'javascript', 'provider', 'dir', 'ltr', 'sessionlang', 'setlang', 'true', 'langoption', 'href', 'title', 'language', 'language', 'name', 'spanish', 'native', 'direction', 'enabled', 'plurals', 'formula', 'n', 'domain', 'prefix', 'weight', 'javascript', 'attributes', 'class', 'xml', 'lang', 'hreflang', 'https', 'extlink', 'exttarget', 'extclass', 'extlabel', 'link', 'is', 'external', 'extimgclass', 'exticonplacement', 'extsubdomains', 'extexclude', 'extinclude', 'extcssexclude', 'extcssexplicit', 'extalert', 'extalerttext', 'this', 'link', 'will', 'take', 'you', 'to', 'an', 'external', 'web', 'site', 'mailtoclass', 'mailtolabel', 'link', 'sends', 'extusefontawesome', 'false', 'lazyloader', 'loadimagedelay', 'bootstrap', 'anchorsfix', 'anchorssmoothscrolling', 'formhaserror', 'popoverenabled', 'popoveroptions', 'animation', 'html', 'placement', 'right', 'selector', 'trigger', 'click', 'triggerautoclose', 'title', 'content', 'delay', 'container', 'body', 'tooltipenabled', 'tooltipoptions', 'animation', 'html', 'placement', 'auto', 'left', 'selector', 'trigger', 'hover', 'focus', 'delay', 'container', 'body', 'pasar', 'contenido', 'principalcursosredesso', 'tiprogramacióninternet', 'cosasautomatización', 'infraestructuraciberseguridadpacket', 'tracertodos', 'cursoscarreras', 'profesionalesoportunidades', 'empleowebinarsasesoramiento', 'profesionalrutasinsignias', 'certificacioneshistorias', 'éxitoapoyomásquiénes', 'somospodcastcsr', 'blogformulario', 'búsquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañoliriniciar', 'sesióniniciar', 'sesiónse', 'olvidó', 'contraseñareenviar', 'correo', 'electrónico', 'activacióncanjear', 'token', 'plazaapoyoactualizaciones', 'inicio', 'sesión', 'netacadpara', 'iniciar', 'sesión', 'utilice', 'correo', 'electrónico', 'contraseña', 'iniciar', 'utilice', 'nombre', 'pantalla', 'nombre', 'inicio', 'sesión', 'borre', 'historial', 'caché', 'navegador', 'aún', 'problemas', 'consulte', 'laspreguntas', 'frecuentespara', 'obtener', 'usted', 'usuario', 'idioma', 'árabe', 'haga', 'clic', 'aquípara', 'obtener', 'muestres', 'mensaje', 'vezinicie', 'sesión', 'netacadenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañolhomecursosredesso', 'tiprogramacióninternet', 'cosasautomatización', 'infraestructuraciberseguridadpacket', 'tracertodos', 'cursoscarreras', 'profesionalesoportunidades', 'empleowebinarsasesoramiento', 'profesionalrutasinsignias', 'certificacioneshistorias', 'éxitoapoyomásquiénes', 'somospodcastcsr', 'bloghomeiniciar', 'sesióniniciar', 'sesiónse', 'olvidó', 'contraseñareenviar', 'correo', 'electrónico', 'activacióncanjear', 'token', 'plazaapoyolog', 'out', 'cdata', 'color', 'ffffff', 'link', 'color', 'underline', 'visited', 'color', 'underline', 'hover', 'color', 'color', 'underline', 'active', 'color', 'underline', 'color', 'important', 'important', 'media', 'only', 'screen', 'and', 'media', 'only', 'screen', 'and', 'and', 'media', 'only', 'screen', 'and', 'url', 'p', 'p', 'color', 'color', 'fff', 'center', 'none', 'hover', 'visited', 'focus', 'color', 'fff', 'important', 'none', 'important', 'hover', 'important', 'padding', 'padding', 'padding', 'padding', 'padding', 'pa ...

# %%
#Verificar frecuencia de palabras 
freq_clean = nltk.FreqDist(clean_tokens)
for key,val in freq_clean.items():
    print (str(key) + ':' + str(val))
# Out:
# cisco:5
# networking:5
# academy:4
# builds:1
# it:1
# skills:2
# education:1
# for:3
# future:1
# loader:1
# configuration:2
# window:6
# datalayer:3
# new:2
# date:2
# event:1
# of:2
# gtm:1
# function:6
# config:1
# enable:1
# true:3
# var:3
# sc:2
# script:1
# type:1
# charset:1
# url:3
# https:2
# http:1
# src:1
# basepath:1
# pathprefix:1
# sethasjscookie:1
# ajaxpagestate:1
# theme:1
# prelogin:1
# js:1
# public:2
# css:1
# urlisajaxtrusted:1
# language:4
# jswidget:1
# widget:1
# ddslick:1
# width:2
# height:4
# showselectedhtml:1
# imageposition:1
# left:3
# selectedoption:1
# globallang:1
# name:2
# spanish:2
# native:2
# direction:2
# enabled:2
# plurals:2
# formula:2
# n:2
# domain:2
# prefix:2
# weight:2
# javascript:2
# provider:1
# dir:1
# ltr:1
# sessionlang:1
# setlang:1
# langoption:1
# href:1
# title:2
# attributes:1
# class:1
# xml:1
# lang:1
# hreflang:1
# extlink:1
# exttarget:1
# extclass:1
# extlabel:1
# link:6
# is:1
# external:2
# extimgclass:1
# exticonplacement:1
# extsubdomains:1
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'error') for word in clean_tokens]

# %%
#Reemplazar tokens sinónimos manual
sinonimos = ['libertad', 'independencia']
for ind,sin in enumerate(sinonimos):
    clean_tokens_sin = [word.replace(sinonimos[ind],'libertad') for word in clean_tokens]

# %%
#Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin.items():
    print (str(key) + ':' + str(val))
# Out:
# cisco:5
# networking:5
# academy:4
# builds:1
# it:1
# skills:2
# education:1
# for:3
# future:1
# loader:1
# configuration:2
# window:6
# datalayer:3
# new:2
# date:2
# event:1
# of:2
# gtm:1
# function:6
# config:1
# enable:1
# true:3
# var:3
# sc:2
# script:1
# type:1
# charset:1
# url:3
# https:2
# http:1
# src:1
# basepath:1
# pathprefix:1
# sethasjscookie:1
# ajaxpagestate:1
# theme:1
# prelogin:1
# js:1
# public:2
# css:1
# urlisajaxtrusted:1
# language:4
# jswidget:1
# widget:1
# ddslick:1
# width:2
# height:4
# showselectedhtml:1
# imageposition:1
# left:3
# selectedoption:1
# globallang:1
# name:2
# spanish:2
# native:2
# direction:2
# enabled:2
# plurals:2
# formula:2
# n:2
# domain:2
# prefix:2
# weight:2
# javascript:2
# provider:1
# dir:1
# ltr:1
# sessionlang:1
# setlang:1
# langoption:1
# href:1
# title:2
# attributes:1
# class:1
# xml:1
# lang:1
# hreflang:1
# extlink:1
# exttarget:1
# extclass:1
# extlabel:1
# link:6
# is:1
# external:2
# extimgclass:1
# exticonplacement:1
# extsubdomains:1
# extexclude:1
# extinclude:1
# extcssexclude:1
# extcssexplicit:1
# extalert:1
# extalerttext:1
# this:1
# will:1
# take:1
# you:1
# to:1
# an:1
# web:2
# site:1
# mailtoclass:1
# mailtolabel:1
# sends:1
# extusefontawesome:1
# false:1
# lazyloader:1
# loadimagedelay:1
# bootstrap:1
# anchorsfix:1
# anchorssmoothscrolling:1
# formhaserror:1
# popoverenabled:1
# popoveroptions:1
# animation:2
# html:2
# placement:2
# right:1
# selector:2
# trigger:2
# click:2
# triggerautoclose:1
# content:1
# delay:2
# container:2
# body:2
# tooltipenabled:1
# tooltipoptions:1
# auto:2
# hover:6
# focus:2
# pasar:1
# contenido:1
# principalcursosredesso:1
# tiprogramacióninternet:2
# cosasautomatización:2
# infraestructuraciberseguridadpacket:2
# tracertodos:2
# cursoscarreras:2
# profesionalesoportunidades:2
# empleowebinarsasesoramiento:2
# profesionalrutasinsignias:2
# certificacioneshistorias:2
# éxitoapoyomásquiénes:2
# somospodcastcsr:2
# blogformulario:1
# búsquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийesp
# pobrezauna:1
# joven:2
# sudafricana:1
# descubrió:1
# pasión:1
# ayudó:1
# pobreza:1
# artículo:3
# estudiante:1
# descubre:1
# oportunidadesun:1
# programa:3
# innovador:1
# currículo:2
# ccna:1
# despertaron:1
# interés:1
# pusieron:1
# libertad:1
# mujeres:2
# lideran:1
# ejemplouna:1
# universidad:1
# arabia:1
# saudita:1
# adoptó:1
# expandir:1
# opciones:1
# empleo:1
# ayudarlas:1
# progresar:1
# vea:1
# historias:1
# respuestas:1
# encuesta:1
# año:1
# fiscal:1
# tomaron:1
# certificación:1
# ayuda:1
# pregunte:1
# nuestroasistente:1
# somosencuentre:1
# academiaapoyoenseña:1
# nosotroscontrate:1
# nosotrossea:1
# partnersíganoscisco:1
# global:1
# educación:1
# ciberseguridad:1
# asocia:1
# instituciones:1
# aprendizaje:1
# mundo:1
# empoderar:1
# personas:1
# profesionales:1
# deresponsabilidad:1
# social:1
# corporativamás:1
# grande:1
# larga:1
# duración:1
# condicionesdeclaración:1
# privacidadpolítica:1
# cookiesprotección:1
# datosaccesibilidadmarcas:1
# comerciales:1
# display:1
# attach:1
# context:1
# settings:1
# img:1
# distance:1
# icon:1
# jquery:1

# %%
#Visualizar Tokens
freq_clean_sin.plot(30, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 3b. Obtener Antónimos

# %%
from nltk.corpus import wordnet
 
antonyms = []
 
for syn in wordnet.synsets("good"):
 
    for l in syn.lemmas():
 
        if l.antonyms():
 
            antonyms.append(l.antonyms()[0].name())
 
print(antonyms)
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %% [markdown]
# # 4. Derivación Regresiva

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('eating'))
# Out:
# eat

# %%
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
# Out:
# trabaj
# trabaj

# %%
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]

# %%
clean_tokens_sin_stems
# Out:
# ['cisc',
#  'networking',
#  'academy',
#  'builds',
#  'it',
#  'skills',
#  'education',
#  'for',
#  'futur',
#  'load',
#  'configuration',
#  'window',
#  'datalay',
#  'window',
#  'datalay',
#  'window',
#  'datalay',
#  'new',
#  'dat',
#  'event',
#  'of',
#  'gtm',
#  'configuration',
#  'window',
#  'new',
#  'dat',
#  'function',
#  'config',
#  'enabl',
#  'tru',
#  'window',
#  'window',
#  'var',
#  'sc',
#  'script',
#  'type',
#  'charset',
#  'var',
#  'url',
#  'https',
#  'http',
#  'src',
#  'url',
#  'sc',
#  'basepath',
#  'pathprefix',
#  'sethasjscooki',
#  'ajaxpagestat',
#  'them',
#  'prelogin',
#  'js',
#  'public',
#  'public',
#  'css',
#  'urlisajaxtrust',
#  'tru',
#  'languag',
#  'jswidget',
#  'widget',
#  'ddslick',
#  'width',
#  'height',
#  'showselectedhtml',
#  'imageposition',
#  'left',
#  'selectedoption',
#  'globallang',
#  'languag',
#  'nam',
#  'spanish',
#  'nativ',
#  'direction',
#  'enabl',
#  'plurals',
#  'formul',
#  'n',
#  'domain',
#  'prefix',
#  'weight',
#  'javascript',
#  'provid',
#  'dir',
#  'ltr',
#  'sessionlang',
#  'setlang',
#  'tru',
#  'langoption',
#  'href',
#  'titl',
#  'languag',
#  'languag',
#  'nam',
#  'spanish',
#  'nativ',
#  'direction',
#  'enabl',
#  'plurals',
#  'formul',
#  'n',
#  'domain',
#  'prefix',
#  'weight',
#  'javascript',
#  'attribut',
#  'class',
#  'xml',
#  'lang',
#  'hreflang',
#  'https',
#  'extlink',
#  'exttarget',
#  'extclass',
#  'extlabel',
#  'link',
#  'is',
#  'external',
#  'extimgclass',
#  'exticonplacement',
#  'extsubdomains',
#  'extexclud',
#  'extinclud',
#  'extcssexclud',
#  'extcssexplicit',
#  'extalert',
#  'extalerttext',
#  'this',
#  'link',
#  'will',
#  'tak',
#  'you',
#  'to',
#  'an',
#  'external',
#  'web',
#  'sit',
#  'mailtoclass',
#  'mailtolabel',
#  'link',
#  'sends',
#  'extusefontawesom',
#  'fals',
#  'lazyload',
#  'loadimagedelay',
#  'bootstrap',
#  'anchorsfix',
#  'anchorssmoothscrolling',
#  'formhaserror',
#  'popoverenabl',
#  'popoveroptions',
#  'animation',
#  'html',
#  'placement',
#  'right',
#  'selector',
#  'trigg',
#  'click',
#  'triggerautoclos',
#  'titl',
#  'content',
#  'delay',
#  'contain',
#  'body',
#  'tooltipenabl',
#  'tooltipoptions',
#  'animation',
#  'html',
#  'placement',
#  'aut',
#  'left',
#  'selector',
#  'trigg',
#  'hov',
#  'focus',
#  'delay',
#  'contain',
#  'body',
#  'pas',
#  'conten',
#  'principalcursosredess',
#  'tiprogramacioninternet',
#  'cosasautomatiz',
#  'infraestructuraciberseguridadpacket',
#  'tracertod',
#  'cursoscarrer',
#  'profesionalesoportun',
#  'empleowebinarsasesor',
#  'profesionalrutasinsigni',
#  'certificacioneshistori',
#  'exitoapoyomasquien',
#  'somospodcastcsr',
#  'blogformulari',
#  'busquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañolirinici',
#  'sesioninici',
#  'sesions',
#  'olvid',
#  'contraseñareenvi',
#  'corre',
#  'electron',
#  'activacioncanj',
#  'tok',
#  'plazaapoyoactualiz',
#  'inici',
#  'sesion',
#  'netacadp',
#  'inici',
#  'sesion',
#  'utilic',
#  'corre',
#  'electron',
#  'contraseñ',
#  'inici',
#  'utilic',
#  'nombr',
#  'pantall',
#  'nombr',
#  'inici',
#  'sesion',
#  'borr',
#  'historial',
#  'cach',
#  'naveg',
#  'aun',
#  'problem',
#  'consult',
#  'laspregunt',
#  'frecuentesp',
#  'obten',
#  'usted',
#  'usuari',
#  'idiom',
#  'arab',
#  'hag',
#  'clic',
#  'aquip',
#  'obten',
#  'muestr',
#  'mensaj',
#  'vezinici',
#  'sesion',
#  'netacadenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañolhomecursosredess',
#  'tiprogramacioninternet',
#  'cosasautomatiz',
#  'infraestructuraciberseguridadpacket',
#  'tracertod',
#  'cursoscarrer',
#  'profesionalesoportun',
#  'empleowebinarsasesor',
#  'profesionalrutasinsigni',
#  'certificacioneshistori',
#  'exitoapoyomasquien',
#  'somospodcastcsr',
#  'bloghomeinici',
#  'sesioninici',
#  'sesions',
#  'olvid',
#  'contraseñareenvi',
#  'corre',
#  'electron',
#  'activacioncanj',
#  'tok',
#  'plazaapoyolog',
#  'out',
#  'cdat',
#  'color',
#  'ffffff',
#  'link',
#  'color',
#  'underlin',
#  'visit',
#  'color',
#  'underlin',
#  'hov',
#  'color',
#  'color',
#  'underlin',
#  'activ',
#  'color',
#  'underlin',
#  'color',
#  'important',
#  'important',
#  'medi',
#  'only',
#  'scre',
#  'and',
#  'medi',
#  'only',
#  'scre',
#  'and',
#  'and',
#  'medi',
#  'only',
#  'scre',
#  'and',
#  'url',
#  'p',
#  'p',
#  'color',
#  'color',
#  'fff',
#  'cent',
#  'non',
#  'hov',
#  'visit',
#  'focus',
#  'color',
#  'fff',
#  'important',
#  'non',
#  'important',
#  'hov',
#  'important',
#  'padding',
#  'padding',
#  'padding',
#  'padding',
#  'padding',
#  'padding',
#  'padding',
#  'important',
#  'important',
#  'bord',
#  'non',
#  'important',
#  'important',
#  'color',
#  'color',
#  'important',
#  'color',
#  'important',
#  'important',
#  'color',
#  'height',
#  'link',
#  'color',
#  'visit',
#  'color',
#  'hov',
#  'color',
#  'activ',
#  'color',
#  'link',
#  'color',
#  'visit',
#  'color',
#  'hov',
#  'color',
#  'activ',
#  'color',
#  'padding',
#  'important',
#  'padding',
#  'padding',
#  'sol',
#  'dfdfdf',
#  'height',
#  'position',
#  'absolut',
#  'left',
#  'top',
#  'sol',
#  'width',
#  'height',
#  'aut',
#  'tecnolog',
#  'consig',
#  'trabaj',
#  'list',
#  'comenz',
#  'cambi',
#  'impuls',
#  'carrer',
#  'cisc',
#  'networking',
#  'academy',
#  'ofrec',
#  'curs',
#  'alin',
#  'certif',
#  'tem',
#  'tal',
#  'comocibersegur',
#  'millonesd',
#  'estudi',
#  'inici',
#  'ofrec',
#  'prest',
#  'servici',
#  'estudi',
#  'obtuv',
#  'trabaj',
#  'nuev',
#  'oportun',
#  'educ',
#  'explor',
#  'cursosdesarroll',
#  'expert',
#  'tecnolog',
#  'funcion',
#  'cienci',
#  'aprendizajeredescybersecurityinternet',
#  'cosasprogramacionautomatiz',
#  'infraestructuracurs',
#  'depacket',
#  'curs',
#  'ofrec',
#  'actual',
#  'siti',
#  'web',
#  'skills',
#  'for',
#  'redirig',
#  'siti',
#  'webhabil',
#  'todoscon',
#  'cisc',
#  'vez',
#  'alli',
#  'hag',
#  'clic',
#  'comienc',
#  'inscrib',
#  'ventan',
#  'abiert',
#  'seleccion',
#  'enlac',
#  'habil',
#  'cdat',
#  'const',
#  'box',
#  'var',
#  'isloggedin',
#  'if',
#  'isloggedin',
#  'isloggedin',
#  'for',
#  'const',
#  'box',
#  'of',
#  'box',
#  'function',
#  'onclick',
#  'settimeout',
#  'function',
#  'click',
#  'function',
#  'comienc',
#  'aprenderdesarroll',
#  'habil',
#  'haran',
#  'solicit',
#  'tod',
#  'line',
#  'gratuitasaprend',
#  'propi',
#  'ritm',
#  'curs',
#  'personaliz',
#  'expert',
#  'sector',
#  'junt',
#  'tarjet',
#  'identif',
#  'prepares',
#  'certif',
#  'reconoc',
#  'tod',
#  'clasesaprendizaj',
#  'personaaprend',
#  'educ',
#  'expert',
#  'academi',
#  'ubic',
#  'cerc',
#  'ticiud',
#  'provinci',
#  'distrit',
#  'codig',
#  'prepar',
#  'carrer',
#  'profesional',
#  'cubr',
#  'certif',
#  'comoccnaypython',
#  'institut',
#  'valid',
#  'habil',
#  'curs',
#  'alin',
#  'credencial',
#  'informacioncoincident',
#  'trabajocoincident',
#  'trabajodescubr',
#  'quien',
#  'contrat',
#  'obteng',
#  'acces',
#  'prioritari',
#  'oportun',
#  'deamazon',
#  'ibm',
#  'verizony',
#  'partners',
#  'enseñarenseñ',
#  'pasion',
#  'part',
#  'comun',
#  'educ',
#  'recurs',
#  'didact',
#  'gratuitosel',
#  'equip',
#  'softwar',
#  'necesitaoportun',
#  'desarroll',
#  'profesionalayud',
#  'estudi',
#  'obten',
#  'emple',
#  'motor',
#  'coincident',
#  'empleosmas',
#  'contrat',
#  'mejor',
#  'talent',
#  'automatiz',
#  'conexion',
#  'empleador',
#  'mejor',
#  'talent',
#  'partners',
#  'educ',
#  'cisc',
#  'networking',
#  'academysin',
#  'talent',
#  'bridgecolabor',
#  'logr',
#  'impact',
#  'socials',
#  'unir',
#  'lasnacion',
#  'unid',
#  'lacas',
#  'blancay',
#  'much',
#  'organizacionessin',
#  'fin',
#  'lucroqu',
#  'conoc',
#  'asociamosinspiresehistori',
#  'exit',
#  'inspir',
#  'estudi',
#  'educ',
#  'prep',
#  'camin',
#  'sal',
#  'pobrezaun',
#  'jov',
#  'sudafrican',
#  'descubr',
#  'pasion',
#  'tecnolog',
#  'ayud',
#  'sal',
#  'pobrez',
#  'articul',
#  'estudi',
#  'descubr',
#  'oportunidadesun',
#  'program',
#  'innov',
#  'curricul',
#  'ccna',
#  'despert',
#  'interes',
#  'jov',
#  'pus',
#  'camin',
#  'libert',
#  'articul',
#  'mujer',
#  'lider',
#  'ejemploun',
#  'univers',
#  'arabi',
#  'saudit',
#  'adopt',
#  'curricul',
#  'cisc',
#  'networking',
#  'academy',
#  'expand',
#  'opcion',
#  'emple',
#  'mujer',
#  'ayud',
#  'progres',
#  'desarroll',
#  'articul',
#  'vea',
#  'tod',
#  'histori',
#  'funcion',
#  'respuest',
#  'encuest',
#  'año',
#  'fiscal',
#  'estudi',
#  'tom',
#  'curs',
#  'alin',
#  'certif',
#  'ayud',
#  'pregunt',
#  'nuestroasistent',
#  'somosencuentr',
#  'academiaapoyoenseñ',
#  'nosotroscontrat',
#  'nosotrosse',
#  'partnersiganoscisc',
#  'networking',
#  'academy',
#  'program',
#  'global',
#  'educ',
#  'cibersegur',
#  'asoci',
#  'institu',
#  'aprendizaj',
#  'mund',
#  'empoder',
#  'tod',
#  'person',
#  'oportun',
#  'profesional',
#  'program',
#  'derespons',
#  'social',
#  'corporativamas',
#  'grand',
#  'larg',
#  'duracion',
#  'condicionesdeclar',
#  'privacidadpolit',
#  'cookiesproteccion',
#  'datosaccesibilidadmarc',
#  'comercial',
#  'cdat',
#  'display',
#  'non',
#  'important',
#  'function',
#  'attach',
#  'function',
#  'context',
#  'settings',
#  'img',
#  'distanc',
#  'icon',
#  'jquery']

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_stems = nltk.FreqDist(clean_tokens_sin_stems)
for key,val in freq_clean_sin_stems.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_stems.plot(30, cumulative=False)
# Out:
# cisc:5
# networking:5
# academy:4
# builds:1
# it:1
# skills:2
# education:1
# for:3
# futur:1
# load:1
# configuration:2
# window:6
# datalay:3
# new:2
# dat:2
# event:1
# of:2
# gtm:1
# function:6
# config:1
# enabl:3
# tru:3
# var:3
# sc:2
# script:1
# type:1
# charset:1
# url:3
# https:2
# http:1
# src:1
# basepath:1
# pathprefix:1
# sethasjscooki:1
# ajaxpagestat:1
# them:1
# prelogin:1
# js:1
# public:2
# css:1
# urlisajaxtrust:1
# languag:4
# jswidget:1
# widget:1
# ddslick:1
# width:2
# height:4
# showselectedhtml:1
# imageposition:1
# left:3
# selectedoption:1
# globallang:1
# nam:2
# spanish:2
# nativ:2
# direction:2
# plurals:2
# formul:2
# n:2
# domain:2
# prefix:2
# weight:2
# javascript:2
# provid:1
# dir:1
# ltr:1
# sessionlang:1
# setlang:1
# langoption:1
# href:1
# titl:2
# attribut:1
# class:1
# xml:1
# lang:1
# hreflang:1
# extlink:1
# exttarget:1
# extclass:1
# extlabel:1
# link:6
# is:1
# external:2
# extimgclass:1
# exticonplacement:1
# extsubdomains:1
# extexclud:1
# extinclud:1
# extcssexclud:1
# extcssexplicit:1
# extalert:1
# extalerttext:1
# this:1
# will:1
# tak:1
# you:1
# to:1
# an:1
# web:2
# sit:1
# mailtoclass:1
# mailtolabel:1
# sends:1
# extusefontawesom:1
# fals:1
# lazyload:1
# loadimagedelay:1
# bootstrap:1
# anchorsfix:1
# anchorssmoothscrolling:1
# formhaserror:1
# popoverenabl:1
# popoveroptions:1
# animation:2
# html:2
# placement:2
# right:1
# selector:2
# trigg:2
# click:2
# triggerautoclos:1
# content:1
# delay:2
# contain:2
# body:2
# tooltipenabl:1
# tooltipoptions:1
# aut:2
# hov:6
# focus:2
# pas:1
# conten:1
# principalcursosredess:1
# tiprogramacioninternet:2
# cosasautomatiz:2
# infraestructuraciberseguridadpacket:2
# tracertod:2
# cursoscarrer:2
# profesionalesoportun:2
# empleowebinarsasesor:2
# profesionalrutasinsigni:2
# certificacioneshistori:2
# exitoapoyomasquien:2
# somospodcastcsr:2
# blogformulari:1
# busquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийesp
# camin:2
# sal:2
# pobrezaun:1
# jov:2
# sudafrican:1
# descubr:2
# ayud:3
# pobrez:1
# articul:3
# oportunidadesun:1
# program:3
# innov:1
# curricul:2
# ccna:1
# despert:1
# interes:1
# pus:1
# libert:1
# mujer:2
# lider:1
# ejemploun:1
# univers:1
# arabi:1
# saudit:1
# adopt:1
# expand:1
# opcion:1
# progres:1
# vea:1
# histori:1
# respuest:1
# encuest:1
# año:1
# fiscal:1
# tom:1
# pregunt:1
# nuestroasistent:1
# somosencuentr:1
# academiaapoyoenseñ:1
# nosotroscontrat:1
# nosotrosse:1
# partnersiganoscisc:1
# global:1
# cibersegur:1
# asoci:1
# institu:1
# aprendizaj:1
# mund:1
# empoder:1
# person:1
# derespons:1
# social:1
# corporativamas:1
# grand:1
# larg:1
# duracion:1
# condicionesdeclar:1
# privacidadpolit:1
# cookiesproteccion:1
# datosaccesibilidadmarc:1
# comercial:1
# display:1
# attach:1
# context:1
# settings:1
# img:1
# distanc:1
# icon:1
# jquery:1
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # 5. Lematizar palabras

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('working', pos="v")) #sustantivos de manera predeterminada, especificar "v" si se quieren los verbos
# Out:
# work

# %%
#Alternativa para texto en español --- Instalar spicy: pip install spicy
import spicy
import spacy
nlp = spacy.blank('es')

# %%
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
# Out:
# cisco
# networking
# academy
# builds
# it
# skills
# education
# for
# future
# loader
# configuration
# window
# datalayer
# window
# datalayer
# window
# datalayer
# new
# date
# event
# of
# gtm
# configuration
# window
# new
# date
# function
# config
# enable
# true
# window
# window
# var
# sc
# script
# type
# charset
# var
# url
# https
# http
# src
# url
# sc
# basepath
# pathprefix
# sethasjscookie
# ajaxpagestate
# theme
# prelogin
# js
# public
# public
# css
# urlisajaxtrusted
# true
# language
# jswidget
# widget
# ddslick
# width
# height
# showselectedhtml
# imageposition
# left
# selectedoption
# globallang
# language
# name
# spanish
# native
# direction
# enabled
# plurals
# formula
# n
# domain
# prefix
# weight
# javascript
# provider
# dir
# ltr
# sessionlang
# setlang
# true
# langoption
# href
# title
# language
# language
# name
# spanish
# native
# direction
# enabled
# plurals
# formula
# n
# domain
# prefix
# weight
# javascript
# attributes
# class
# xml
# lang
# hreflang
# https
# extlink
# exttarget
# extclass
# extlabel
# link
# is
# external
# extimgclass
# exticonplacement
# extsubdomains
# extexclude
# extinclude
# extcssexclude
# extcssexplicit
# extalert
# extalerttext
# this
# link
# will
# take
# you
# to
# an
# external
# web
# site
# mailtoclass
# mailtolabel
# link
# sends
# extusefontawesome
# false
# lazyloader
# loadimagedelay
# bootstrap
# anchorsfix
# anchorssmoothscrolling
# formhaserror
# popoverenabled
# popoveroptions
# animation
# html
# placement
# right
# selector
# trigger
# click
# triggerautoclose
# title
# content
# delay
# container
# body
# tooltipenabled
# tooltipoptions
# animation
# html
# placement
# auto
# left
# selector
# trigger
# hover
# focus
# delay
# container
# body
# pasar
# contenido
# principalcursosredesso
# tiprogramacióninternet
# cosasautomatización
# infraestructuraciberseguridadpacket
# tracertodos
# cursoscarreras
# profesionalesoportunidades
# empleowebinarsasesoramiento
# profesionalrutasinsignias
# certificacioneshistorias
# éxitoapoyomásquiénes
# somospodcastcsr
# blogformulario
# búsquedabuscarenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañoliriniciar
# sesióniniciar
# sesiónse
# olvidó
# contraseñareenviar
# correo
# electrónico
# activacióncanjear
# token
# plazaapoyoactualizaciones
# inicio
# sesión
# netacadpara
# iniciar
# sesión
# utilice
# correo
# electrónico
# contraseña
# iniciar
# utilice
# nombre
# pantalla
# nombre
# inicio
# sesión
# borre
# historial
# caché
# navegador
# aún
# problemas
# consulte
# laspreguntas
# frecuentespara
# obtener
# usted
# usuario
# idioma
# árabe
# haga
# clic
# aquípara
# obtener
# muestres
# mensaje
# vezinicie
# sesión
# netacadenglishالعربية简体中文繁體中文français日本語portuguêsрусскийespañolhomecursosredesso
# tiprogramacióninternet
# cosasautomatización
# infraestructuraciberseguridadpacket
# tracertodos
# cursoscarreras
# profesionalesoportunidades
# empleowebinarsasesoramiento
# profesionalrutasinsignias
# certificacioneshistorias
# éxitoapoyomásquiénes
# somospodcastcsr
# bloghomeiniciar
# sesióniniciar
# sesiónse
# olvidó
# contraseñareenviar
# correo
# electrónico
# activacióncanjear
# token
# plazaapoyolog
# out
# cdata
# color
# ffffff
# link
# color
# underline
# visited
# color
# underline
# hover
# color
# color
# underline
# active
# color
# underline
# color
# important
# important
# media
# only
# screen
# and
# media
# only
# screen
# and
# and
# media
# only
# screen
# and
# url
# p
# p
# color
# color
# fff
# center
# none
# hover
# visited
# focus
# color
# fff
# important
# none
# important
# hover
# important
# padding
# padding
# padding
# padding
# padding
# padding
# padding
# important
# important
# border
# none
# important
# important
# color
# color
# important
# color
# important
# important
# color
# height
# link
# color
# visited
# color
# hover
# color
# active
# color
# link
# color
# visited
# color
# hover
# color
# active
# color
# padding
# important
# padding
# padding
# solid
# dfdfdf
# height
# position
# absolute
# left
# top
# solid
# width
# height
# auto
# tecnología
# consiga
# trabajo
# listo
# comenzar
# cambiar
# impulsar
# carrera
# cisco
# networking
# academy
# ofrece
# cursos
# alineados
# certificaciones
# temas
# tales
# comociberseguridad
# millonesde
# estudiantes
# inicios
# ofrecen
# prestamos
# servicios
# estudiantes
# obtuvieron
# trabajo
# nueva
# oportunidad
# educativa
# explore
# cursosdesarrollado
# expertos
# tecnología
# función
# ciencia
# aprendizajeredescybersecurityinternet
# cosasprogramaciónautomatización
# infraestructuracursos
# depacket
# curso
# ofrece
# actualmente
# sitio
# web
# skills
# for
# redirigirá
# sitio
# webhabilidades
# todoscon
# cisco
# vez
# allí
# haga
# clic
# comience
# inscribirse
# ventana
# abierto
# seleccione
# enlace
# habilidades
# cdata
# const
# boxes
# var
# isloggedin
# if
# isloggedin
# isloggedin
# for
# const
# box
# of
# boxes
# function
# onclick
# settimeout
# function
# click
# function
# comience
# aprenderdesarrolle
# habilidades
# harán
# soliciten
# todas
# línea
# gratuitasaprenda
# propio
# ritmo
# cursos
# personalizados
# expertos
# sector
# junte
# tarjetas
# identificación
# prepárese
# certificaciones
# reconocidas
# todas
# clasesaprendizaje
# personaaprenda
# educadores
# expertos
# academia
# ubicación
# cerca
# ticiudad
# provincia
# distrito
# código
# preparando
# carrera
# profesional
# cubrimos
# certificaciones
# comoccnaypython
# institute
# validar
# habilidades
# cursos
# alinean
# credenciales
# informacióncoincidencia
# trabajocoincidencia
# trabajodescubra
# quién
# contratando
# obtenga
# acceso
# prioritario
# oportunidades
# deamazon
# ibm
# verizony
# partners
# enseñarenseñe
# pasiones
# parte
# comunidad
# educadores
# recursos
# didácticos
# gratuitosel
# equipo
# software
# necesitaoportunidades
# desarrollo
# profesionalayude
# estudiantes
# obtener
# empleos
# motor
# coincidencia
# empleosmás
# contratar
# mejores
# talentos
# automatizamos
# conexión
# empleadores
# mejores
# talentos
# partners
# educativos
# cisco
# networking
# academysin
# talent
# bridgecolaboremos
# lograr
# impacto
# socialse
# unirá
# lasnaciones
# unidas
# lacasa
# blancay
# muchas
# organizacionessin
# fines
# lucroque
# conoce
# asociamosinspíresehistorias
# éxito
# inspiradoras
# estudiantes
# educadores
# prepara
# camino
# salir
# pobrezauna
# joven
# sudafricana
# descubrió
# pasión
# tecnología
# ayudó
# salir
# pobreza
# artículo
# estudiante
# descubre
# oportunidadesun
# programa
# innovador
# currículo
# ccna
# despertaron
# interés
# joven
# pusieron
# camino
# libertad
# artículo
# mujeres
# lideran
# ejemplouna
# universidad
# arabia
# saudita
# adoptó
# currículo
# cisco
# networking
# academy
# expandir
# opciones
# empleo
# mujeres
# ayudarlas
# progresar
# desarrollo
# artículo
# vea
# todas
# historias
# función
# respuestas
# encuesta
# año
# fiscal
# estudiantes
# tomaron
# cursos
# alineados
# certificación
# ayuda
# pregunte
# nuestroasistente
# somosencuentre
# academiaapoyoenseña
# nosotroscontrate
# nosotrossea
# partnersíganoscisco
# networking
# academy
# programa
# global
# educación
# ciberseguridad
# asocia
# instituciones
# aprendizaje
# mundo
# empoderar
# todas
# personas
# oportunidades
# profesionales
# programa
# deresponsabilidad
# social
# corporativamás
# grande
# larga
# duración
# condicionesdeclaración
# privacidadpolítica
# cookiesprotección
# datosaccesibilidadmarcas
# comerciales
# cdata
# display
# none
# important
# function
# attach
# function
# context
# settings
# img
# distance
# icon
# jquery

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin_lem)
for key,val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# :662
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
